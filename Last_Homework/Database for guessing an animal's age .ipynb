# %%
import pandas as pd
df = pd.read_csv('CrabAgePrediction.csv')
df
# Out:
#      Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0      F  1.4375    1.1750  0.4125  24.635715       12.332033        5.584852
# 1      M  0.8875    0.6500  0.2125   5.400580        2.296310        1.374951
# 2      I  1.0375    0.7750  0.2500   7.952035        3.231843        1.601747
# 3      F  1.1750    0.8875  0.2500  13.480187        4.748541        2.282135
# 4      I  0.8875    0.6625  0.2125   6.903103        3.458639        1.488349
# ...   ..     ...       ...     ...        ...             ...             ...
# 3888   F  1.4625    1.1375  0.3250  24.819987       11.651644        5.854172
# 3889   F  1.5500    1.2125  0.4375  34.458817       15.450477        7.172423
# 3890   I  0.6250    0.4625  0.1625   2.012815        0.765436        0.524466
# 3891   I  1.0625    0.7750  0.2625  10.347568        4.507570        2.338834
# 3892   I  0.7875    0.6125  0.2125   4.068153        1.502523        1.346601
#
#       Shell Weight  Age
# ...

# %%
df.shape
df.describe
# these are some simple functions for viewing our dataset and its values
# Out:
# <bound method NDFrame.describe of      Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0      F  1.4375    1.1750  0.4125  24.635715       12.332033        5.584852
# 1      M  0.8875    0.6500  0.2125   5.400580        2.296310        1.374951
# 2      I  1.0375    0.7750  0.2500   7.952035        3.231843        1.601747
# 3      F  1.1750    0.8875  0.2500  13.480187        4.748541        2.282135
# 4      I  0.8875    0.6625  0.2125   6.903103        3.458639        1.488349
# ...   ..     ...       ...     ...        ...             ...             ...
# 3888   F  1.4625    1.1375  0.3250  24.819987       11.651644        5.854172
# 3889   F  1.5500    1.2125  0.4375  34.458817       15.450477        7.172423
# 3890   I  0.6250    0.4625  0.1625   2.012815        0.765436        0.524466
# 3891   I  1.0625    0.7750  0.2625  10.347568        4.507570        2.338834
# 3892   I  0.7875    0.6125  0.2125   4.068153        1.502523        1.346601
#
# ...

# %%
#In this step we will work on Learning and predicting
# We will ask our AI to predict the Gender(sex) of Crab according to their data
from sklearn.tree import DecisionTreeClassifier

X = df.drop(columns=['Sex'])
y = df['Sex']

model = DecisionTreeClassifier()
model.fit(X.values, y)

predictions_ID = model.predict([[11.7225, 2.1450, 4.5125, 6.678715, 22.323033, 4.6784852, 7.747181, 10]])
predictions_ID
# Out:
# array(['M'], dtype=object)

# %%
#On this step we will Calculate the accuracy of our test
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

df = pd.read_csv('CrabAgePrediction.csv')
X = df.drop(columns=['Sex'])
y = df['Sex']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

score_ID = accuracy_score(y_test, predictions)
score_ID
# Out:
# 0.5083440308087291

# %%
#on this step we will work on persisting models
import joblib
#In the video he uses another function but it did not work for me so I used this function instead
joblib.dump(model, 'Crab_Gender.joblib')
#In this step we are trying to see if the model works the way we want it to 
model = joblib.load('Crab_Gender.joblib')
model.fit(X.values, y)
predictions = model.predict([[2.4475, 4.6750, 66.7125, 31.535715, 22.332033, 23.584852, 4.757181, 6]])
predictions
# Out:
# array(['M'], dtype=object)

# %%
#This is the last step where we visualize our code 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

df = pd.read_csv('CrabAgePrediction.csv')
X = df.drop(columns=['Sex'])
y = df['Sex']
    
model = DecisionTreeClassifier()
model.fit(X.values, y)

tree.export_graphviz(model, out_file='Crab_Gender.dot',
                    feature_names=['Length','Diameter','Height','Weight','Shucked Weight','Viscera Weight','Shell Weight','Age'],
                    class_names=sorted(y.unique()),
                    label='all',
                    rounded=True,
                    filled=True) 
# For further more
